# %% [markdown]
# >  Q. Add the current date to the text file today.txt as a string.

# %%
import datetime
from datetime import date
now = date.today()
cur_date = now.isoformat()
cur_date
# Out:
# '2023-05-30'

# %%
with open('today.txt','w') as file:
    file.write(cur_date)

# %% [markdown]
# > Q. Read the text file today.txt into the string today_string

# %%
with open('today.txt','r') as file:
    today_string = file.read()
today_string
# Out:
# '2023-05-30'

# %% [markdown]
# > Q. Parse the date from today_string.

# %%
from datetime import datetime
format = '%Y-%m-%d'
datetime.strptime(today_string,format)
# Out:
# datetime.datetime(2023, 5, 30, 0, 0)

# %% [markdown]
# > Q. List the files in your current directory

# %%
import os
os.listdir('.')
# Out:
# ['books.csv',
#  'books.db',
#  'FSDS_Python_Basics_Assignment_1.docx',
#  'FSDS_Python_Basics_Assignment_10.docx',
#  'FSDS_Python_Basics_Assignment_11.docx',
#  'FSDS_Python_Basics_Assignment_12.docx',
#  'FSDS_Python_Basics_Assignment_13.docx',
#  'FSDS_Python_Basics_Assignment_14.docx',
#  'FSDS_Python_Basics_Assignment_15.docx',
#  'FSDS_Python_Basics_Assignment_16.docx',
#  'FSDS_Python_Basics_Assignment_17.ipynb',
#  'FSDS_Python_Basics_Assignment_18.ipynb',
#  'FSDS_Python_Basics_Assignment_19.ipynb',
#  'FSDS_Python_Basics_Assignment_2.docx',
#  'FSDS_Python_Basics_Assignment_20.ipynb',
#  'FSDS_Python_Basics_Assignment_21.ipynb',
#  'FSDS_Python_Basics_Assignment_22.ipynb',
#  'FSDS_Python_Basics_Assignment_23.ipynb',
#  'FSDS_Python_Basics_Assignment_24.ipynb',
#  'FSDS_Python_Basics_Assignment_25.ipynb',
#  'FSDS_Python_Basics_Assignment_3.docx',
#  'FSDS_Python_Basics_Assignment_4.docx',
#  'FSDS_Python_Basics_Assignment_5.docx',
#  'FSDS_Python_Basics_Assignment_6.docx',
#  'FSDS_Python_Basics_Assignment_7.docx',
#  'FSDS_Python_Basics_Assignment_8.docx',
#  'FSDS_Python_Basics_Assignment_9.docx',
#  'today.txt']

# %% [markdown]
# > Q.  Use multiprocessing to create three separate processes. Make each one wait a random number of seconds between one and five, print the current time, and then exit.

# %%
import multiprocessing

def printsec(seconds):
    from datetime import datetime
    from time import sleep
    sleep(seconds)
    print('wait', seconds, 'seconds, time is', datetime.utcnow())
    
if __name__ == '__main__':
    import random    
    for n in range(3):
        seconds = random.random()
        proc = multiprocessing.Process(target=printsec, args=(seconds,))
        proc.start()

# %%
# !python abc.py
# Out:
# python: can't open file 'd:\\iNeuron FSDS Assignments\\Python Basics\\abc.py': [Errno 2] No such file or directory

# %% [markdown]
# > Q. Create a date object of your day of birth

# %%
my_dob = date(1998,7,13)
my_dob
# Out:
# datetime.date(1998, 7, 13)

# %% [markdown]
# > Q. What day of the week was your day of birth?

# %%
my_dob.weekday()
# Out:
# 0

# %% [markdown]
# > Q. When will you be (or when were you) 10,000 days old?

# %%
from datetime import timedelta
day10000 = my_dob + timedelta(days=10000)
day10000
# Out:
# datetime.date(2025, 11, 28)
